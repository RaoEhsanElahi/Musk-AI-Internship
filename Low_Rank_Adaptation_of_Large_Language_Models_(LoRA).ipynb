# %% [markdown]
# <a href="https://colab.research.google.com/github/RaoEhsanElahi/Musk-AI-Internship/blob/main/Low_Rank_Adaptation_of_Large_Language_Models_(LoRA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets diffusers accelerate wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 31055, done.
# remote: Counting objects: 100% (931/931), done.
# remote: Compressing objects: 100% (497/497), done.
# remote: Total 31055 (delta 617), reused 606 (delta 375), pack-reused 30124
# Receiving objects: 100% (31055/31055), 22.35 MiB | 16.94 MiB/s, done.
# Resolving deltas: 100% (22687/22687), done.

# %%
"""from huggingface_hub import notebook_login

notebook_login()"""
# Out:
# 'from huggingface_hub import notebook_login\n\nnotebook_login()'

# %%
# %cd ./diffusers
# Out:
# /content/diffusers

# %%
# !dir
# Out:
# CITATION.cff	    docs      MANIFEST.in     scripts	 tests
# CODE_OF_CONDUCT.md  examples  PHILOSOPHY.md   setup.cfg  _typos.toml
# CONTRIBUTING.md     LICENSE   pyproject.toml  setup.py	 utils
# docker		    Makefile  README.md       src

# %%
# !pip install .
# Out:
# Processing /content/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.19.0.dev0-py3-none-any.whl size=1281198 sha256=b4f2077530ead45c3c5d217373e6c3ed1a9a1b5d21a09e98e98624e879c40603
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oskpoktq/wheels/95/c5/3b/e1b4269f8a2584de57e75f949a185b48fc4144e9a91fc9965a
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.18.2
#     Uninstalling diffusers-0.18.2:
#       Successfully uninstalled diffusers-0.18.2
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
# !export MODEL_NAME="runwayml/stable-diffusion-v1-5"
# !export OUTPUT_DIR="EhsanElahi/sddata/finetune/lora/pokemon"
# !export HUB_MODEL_ID="EhsanElahi/pokemon-lora-5000"
# !export DATASET_NAME="EhsanElahi/ehsan"

# %%
# %cd examples/text_to_image
# Out:
# /content/diffusers/examples/text_to_image

# %%
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1-py2.py3-none-any.whl size=16973 sha256=4a5b4824ea991d9332aa7c75d31c45c3ebdaffa26ba224dcc09367eacf417a81
#   Stored in directory: /root/.cache/pip/wheels/6d/29/56/abdffd4c604f255b5254bef3f1c598ab7811ea020540599438
# Successfully built tensorrt
# ...

# %%
# !accelerate launch --mixed_precision="fp16"  train_text_to_image_lora.py \
  --pretrained_model_name_or_path "runwayml/stable-diffusion-v1-5" \
  --dataset_name "EhsanElahi/ehsan" \
  --dataloader_num_workers=8 \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1500 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=0 \
  --output_dir "EhsanElahi/sddata/finetune/lora/pokemon" \
  --push_to_hub \
  --hub_model_id "EhsanElahi/my-avatars-by-LoRA-4" \
  --report_to=wandb \
  --checkpointing_steps=500 \
  --validation_prompt="STABLE DIFFUSION ART of ehsan." \
  --seed=1337
# Out:
# 2023-07-21 12:23:50.872027: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2023-07-21 12:23:58.448484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 07/21/2023 12:24:01 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# {'prediction_type', 'clip_sample_range', 'variance_type', 'dynamic_thresholding_ratio', 'sample_max_value', 'thresholding', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# ...
